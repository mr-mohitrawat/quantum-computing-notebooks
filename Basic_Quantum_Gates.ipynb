# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector, visualize_transition
from numpy import pi

# %%
# function to show gate circuit & its state in bloch sphere
def show_gate(qc):
    display(qc.draw('mpl'))
    display(plot_bloch_multivector(qc))

# %%
# I dentity Gate
qc = QuantumCircuit(1)
qc.id(0)

show_gate(qc)

# %%
# Pauli X Gate | NOT Gate
qc = QuantumCircuit(1)
qc.x(0)

show_gate(qc)

# %%
# Pauli Y Gate
qc = QuantumCircuit(1)
qc.y(0)

show_gate(qc)

# %%
# Pauli Z Gate
qc = QuantumCircuit(1)
qc.z(0)

show_gate(qc)

# %%
# Hadamard H Gate
qc = QuantumCircuit(1)
qc.h(0)

show_gate(qc)

# %%
# Rotation X Gate
qc = QuantumCircuit(1)
qc.rx(pi, 0)

show_gate(qc)

# %%
# Rotation Y Gate
qc = QuantumCircuit(1)
qc.ry(pi, 0)

show_gate(qc)

# %%
# Rotation Z Gate
qc = QuantumCircuit(1)
qc.rz(pi, 0)

show_gate(qc)

# %%
# CNOT | Controlled Not Gate
qc = QuantumCircuit(2)
qc.cx(0, 1)

show_gate(qc)

# %%
# Toffoli Gate Controled Controled Not Gate
qc = QuantumCircuit(3)
qc.ccx(0, 1, 2)

show_gate(qc)
